# %% [markdown]
# <a href="https://colab.research.google.com/github/juligis/CafePoliticoPy/blob/main/Copia_de_transformacion_practice_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('UncleanedCafe.csv',names=['x1','x2','x3','x4','x5','x6','x7','x8','x9','x10','x11','x12','x13'])
df
# Out:
#        x1   x2             x3                 x4                        x5  \
# 0     Año  Mes            Dia         Presidente  Sacos de cafe producidos
# 1       3  ene  jue-02-ene-03  Alvaro Uribe (P1)                    30.800
# 2       3  ene  vie-03-ene-03  Alvaro Uribe (P1)                    30.800
# 3       3  ene  sáb-04-ene-03  Alvaro Uribe (P1)                    30.800
# 4       3  ene  dom-05-ene-03  Alvaro Uribe (P1)                    30.800
# ...   ...  ...            ...                ...                       ...
# 7290   22  dic  mar-27-dic-22         Ivan Duque                    31.645
# 7291   22  dic  mié-28-dic-22         Ivan Duque                    31.645
# 7292   22  dic  jue-29-dic-22         Ivan Duque                    31.645
# 7293   22  dic  vie-30-dic-22         Ivan Duque                    31.645
# 7294   22  dic  sáb-31-dic-22         Ivan Duque                    31.645
#
#                             x6                           x7  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7295 entries, 0 to 7294
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      7295 non-null   object
#  1   x2      7295 non-null   object
#  2   x3      7295 non-null   object
#  3   x4      7295 non-null   object
#  4   x5      7295 non-null   object
#  5   x6      7295 non-null   object
#  6   x7      7295 non-null   object
#  7   x8      7295 non-null   object
#  8   x9      7295 non-null   object
#  9   x10     7295 non-null   object
#  10  x11     7295 non-null   object
#  11  x12     7295 non-null   object
#  12  x13     7295 non-null   object
# dtypes: object(13)
# memory usage: 741.0+ KB

# %%
print(df.isna())
# Out:
#          x1     x2     x3     x4     x5     x6     x7     x8     x9    x10  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7290  False  False  False  False  False  False  False  False  False  False
# 7291  False  False  False  False  False  False  False  False  False  False
# 7292  False  False  False  False  False  False  False  False  False  False
# 7293  False  False  False  False  False  False  False  False  False  False
# 7294  False  False  False  False  False  False  False  False  False  False
#
#         x11    x12    x13
# 0     False  False  False
# ...

# %%
df.head()
# Out:
#     x1   x2             x3                 x4                        x5  \
# 0  Año  Mes            Dia         Presidente  Sacos de cafe producidos
# 1    3  ene  jue-02-ene-03  Alvaro Uribe (P1)                    30.800
# 2    3  ene  vie-03-ene-03  Alvaro Uribe (P1)                    30.800
# 3    3  ene  sáb-04-ene-03  Alvaro Uribe (P1)                    30.800
# 4    3  ene  dom-05-ene-03  Alvaro Uribe (P1)                    30.800
#
#                          x6                           x7  \
# 0  Sacos de cafe exportados  Valor exportacion (Dolares)
# 1                    25.167                    2.233.333
# 2                    25.167                    2.233.333
# 3                    25.167                    2.233.333
# 4                    25.167                    2.233.333
#
#                          x8                     x9                      x10  \
# 0  Kilos de cafe producidos  Factor de rendimiento  Kilos de cafe pergamino
# ...

# %%
df['x6'] = df['x6'].str.replace(".", "")
df['x5'] = df['x5'].str.replace(".", "")
df['x6'] = df['x6'].str.replace(".", "")
df['x7'] = df['x7'].str.replace(".", "")
df['x8'] = df['x8'].str.replace(".", "")
df['x9'] = df['x9'].str.replace(",", ".")
df['x10'] = df['x10'].str.replace(".", "")
df['x11'] = df['x11'].str.replace(".", "")
df['x12'] = df['x12'].str.replace(".", "")
df['x13'] = df['x13'].str.replace(".", "")
df['x9'] = df['x9'].str.replace("%", "")
df
# Out:
# <ipython-input-23-5b187b25484f>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['x6'] = df['x6'].str.replace(".", "")
# <ipython-input-23-5b187b25484f>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['x5'] = df['x5'].str.replace(".", "")
# <ipython-input-23-5b187b25484f>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['x6'] = df['x6'].str.replace(".", "")
# ...

# %%
df['x1'] = pd.to_numeric(df['x1'],errors='coerce')
df['x2'] = pd.to_numeric(df['x2'],errors='coerce')
df['x5'] = pd.to_numeric(df['x5'],errors='coerce')
df['x6'] = pd.to_numeric(df['x6'],errors='coerce')
df['x7'] = pd.to_numeric(df['x7'],errors='coerce')
df['x8'] = pd.to_numeric(df['x8'],errors='coerce')
df['x9'] = pd.to_numeric(df['x9'],errors='coerce')
df['x10'] = pd.to_numeric(df['x10'],errors='coerce')
df['x11'] = pd.to_numeric(df['x11'],errors='coerce')
df['x12'] = pd.to_numeric(df['x12'],errors='coerce')
df['x13'] = pd.to_numeric(df['x13'],errors='coerce')

# %%
df.head()
# Out:
#     x1  x2             x3                 x4       x5       x6         x7  \
# 0  NaN NaN            Dia         Presidente      NaN      NaN        NaN
# 1  3.0 NaN  jue-02-ene-03  Alvaro Uribe (P1)  30800.0  25167.0  2233333.0
# 2  3.0 NaN  vie-03-ene-03  Alvaro Uribe (P1)  30800.0  25167.0  2233333.0
# 3  3.0 NaN  sáb-04-ene-03  Alvaro Uribe (P1)  30800.0  25167.0  2233333.0
# 4  3.0 NaN  dom-05-ene-03  Alvaro Uribe (P1)  30800.0  25167.0  2233333.0
#
#           x8       x9        x10      x11       x12           x13
# 0        NaN      NaN        NaN      NaN       NaN           NaN
# 1  1848000.0  76.0625  2429581.0  19437.0  277000.0  5.383951e+09
# 2  1848000.0  76.0625  2429581.0  19437.0  280875.0  5.459268e+09
# 3  1848000.0  76.0625  2429581.0  19437.0  280875.0  5.459268e+09
# 4  1848000.0  76.0625  2429581.0  19437.0  280875.0  5.459268e+09

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(df, hue="x4")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7295 entries, 0 to 7294
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      7294 non-null   float64
#  1   x2      0 non-null      float64
#  2   x5      7294 non-null   float64
#  3   x6      7294 non-null   float64
#  4   x7      0 non-null      float64
#  5   x8      243 non-null    float64
#  6   x9      0 non-null      float64
#  7   x10     30 non-null     float64
#  8   x11     7294 non-null   float64
#  9   x12     6167 non-null   float64
#  10  x13     0 non-null      float64
# dtypes: float64(11)
# memory usage: 627.0 KB

# %%
df.describe()
# Out:
#                 x1   x2           x5           x6   x7          x8   x9  \
# count  7294.000000  0.0  7294.000000  7294.000000  0.0  243.000000  0.0
# mean     12.490403  NaN    32.064296    29.796966  NaN  885.185086  NaN
# std       5.762530  NaN     8.452870     7.203990  NaN   95.808971  NaN
# min       3.000000  NaN    11.500000    11.129000  NaN  690.000000  NaN
# 25%       7.000000  NaN    26.000000    25.355000  NaN  835.161000  NaN
# 50%      12.000000  NaN    32.333000    30.258000  NaN  918.000000  NaN
# 75%      17.000000  NaN    37.387000    35.226000  NaN  938.000000  NaN
# max      22.000000  NaN    56.226000    46.774000  NaN  996.774000  NaN
#
#                 x10          x11          x12  x13
# count  3.000000e+01  7294.000000  6167.000000  0.0
# mean   9.508900e+02    20.369316   621.231481  NaN
# std    1.156303e-13     5.174550   188.551233  NaN
# min    9.508900e+02     7.607000   277.000000  NaN
# 25%    9.508900e+02    16.758000   454.562500  NaN
# ...

# %%
df = df.drop(columns=['x2'])
df = df.drop(columns=['x13'])

# %%
df.describe()
# Out:
#                 x1           x5           x6   x7          x8   x9  \
# count  7294.000000  7294.000000  7294.000000  0.0  243.000000  0.0
# mean     12.490403    32.064296    29.796966  NaN  885.185086  NaN
# std       5.762530     8.452870     7.203990  NaN   95.808971  NaN
# min       3.000000    11.500000    11.129000  NaN  690.000000  NaN
# 25%       7.000000    26.000000    25.355000  NaN  835.161000  NaN
# 50%      12.000000    32.333000    30.258000  NaN  918.000000  NaN
# 75%      17.000000    37.387000    35.226000  NaN  938.000000  NaN
# max      22.000000    56.226000    46.774000  NaN  996.774000  NaN
#
#                 x10          x11          x12
# count  3.000000e+01  7294.000000  6167.000000
# mean   9.508900e+02    20.369316   621.231481
# std    1.156303e-13     5.174550   188.551233
# min    9.508900e+02     7.607000   277.000000
# 25%    9.508900e+02    16.758000   454.562500
# 50%    9.508900e+02    20.638000   649.125000
# ...

# %%
df = df.drop(columns=['x7'])
df = df.drop(columns=['x9'])

# %%
df.describe()
# Out:
#                 x1           x5           x6          x8           x10  \
# count  7294.000000  7294.000000  7294.000000  243.000000  3.000000e+01
# mean     12.490403    32.064296    29.796966  885.185086  9.508900e+02
# std       5.762530     8.452870     7.203990   95.808971  1.156303e-13
# min       3.000000    11.500000    11.129000  690.000000  9.508900e+02
# 25%       7.000000    26.000000    25.355000  835.161000  9.508900e+02
# 50%      12.000000    32.333000    30.258000  918.000000  9.508900e+02
# 75%      17.000000    37.387000    35.226000  938.000000  9.508900e+02
# max      22.000000    56.226000    46.774000  996.774000  9.508900e+02
#
#                x11          x12
# count  7294.000000  6167.000000
# mean     20.369316   621.231481
# std       5.174550   188.551233
# min       7.607000   277.000000
# 25%      16.758000   454.562500
# 50%      20.638000   649.125000
# 75%      23.610000   780.000000
# max      34.900000   999.250000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7295 entries, 0 to 7294
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      7294 non-null   float64
#  1   x5      7294 non-null   float64
#  2   x6      7294 non-null   float64
#  3   x8      243 non-null    float64
#  4   x10     30 non-null     float64
#  5   x11     7294 non-null   float64
#  6   x12     6167 non-null   float64
# dtypes: float64(7)
# memory usage: 399.1 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(df, hue="x12")
plt.show()
